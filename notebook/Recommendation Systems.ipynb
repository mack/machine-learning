# %%
# Apriori Algorithm - Market basket analysis

def apriori():
# Out:
#   File "<ipython-input-1-11c420bd33c0>", line 3
#     def apriori():
#                    ^
# SyntaxError: unexpected EOF while parsing
