# %%
from nltk import word_tokenize
import nltk

# %%
# word_tokenize("this is a test")
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-8-4e4f4a6ad1ba> in <module>()
#       1 # word_tokenize("this is a test")
# ----> 2 nltk.download()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/nltk/downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error)
#     659             # function should make a new copy of self to use?
#     660             if download_dir is not None: self._download_dir = download_dir
# --> 661             self._interactive_download()
#     662             return True
#     663
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/nltk/downloader.py in _interactive_download(self)
#     980         if TKINTER:
#     981             try:
# ...

# %%
nltk.download()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a1a554e5d735> in <module>()
# ----> 1 nltk.download()
#
# NameError: name 'nltk' is not defined
